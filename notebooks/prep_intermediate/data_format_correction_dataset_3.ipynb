# %%
DATASET = "dataset_3"

# %% [markdown]
# # Introduction and objective
#
# In this notebooks we would like to read the image and annotations data of dataset 3 and save them into a high performance data structure which allows fast write/read at the time of training a deep neural network

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import os
import yaml
import shutil
import glob
from typing import List, Dict, Tuple, Union, Any
from numbers import Number
import h5py
from PIL import Image
import numpy as np
import pandas as pd

# %%
from utils import harmonize_hdf5, read_harmonized_hdf5

# %% [markdown]
# ## current directory

# %%
print(os.getcwd())
# Out:
# /home/samehr/Desktop/cephal/cvmt/notebooks/prep_intermediate

# %% [markdown]
# ## load parameters

# %%
with open("../../code_configs/params.yaml") as f:
    params = yaml.safe_load(f)

# %%
print(params)
# Out:
# {'RAW_DATA_DIRECTORY': '../../data/raw', 'INTERMEDIATE_DATA_DIRECTORY': '../../data/intermediate', 'PRIMARY_DATA_DIRECTORY': '../../data/primary', 'DATASET_1_RAW_ZIP_FILE_NAME': 'radiography-20221212T190109Z-001.zip', 'DATASET_1_RAW_ZIP_NEW_ANNOT_FILE_NAME': 'label_edited-20230122T143005Z-001.zip', 'DATASET_1_INTERMEDIATE_DIR_NAME': 'dataset_1', 'DATASET_1_UNWANTED_JSON_FIELDS': ['imageData'], 'DATASET_3_RAW_RAR_FILE_NAME': 'RawImage.rar', 'DATASET_3_RAW_DIR_NAME_TEMP': 'dataset_3_bmp', 'DATASET_3_RAW_DIR_NAME': 'dataset_3_raw_data', 'UNWANTED_JSON_FIELDS': ['imageData', 'imagePath'], 'DATASET_1_INTERM_DIR_NAME': 'dataset_1_interm_data-20230304T160341Z-001', 'DATASET_1_INTERM_IMG_DIR_NAME': ['image'], 'DATASET_1_INTERM_V_LANDMARKS_DIR_NAME': ['label'], 'DATASET_1_INTERM_F_LANDMARKS_DIR_NAME': None, 'DATASET_2_INTERM_DIR_NAME': 'dataset_2_interm_data-20230304T160421Z-001', 'DATASET_2_INTERM_IMG_DIR_NAME': ['image'], 'DATASET_2_INTERM_V_LANDMARKS_DIR_NAME': ['label'], 'DATASET_2_INTERM_F_LANDMARKS_DIR_NAME': None, 'DATASET_3_INTERM_DIR_NAME': 'dataset_3_interm_data-20230304T160433Z-001', 'DATASET_3_INTERM_IMG_DIR_NAME': ['training/image', 'test1/image', 'test2/image'], 'DATASET_3_INTERM_V_LANDMARKS_DIR_NAME': ['training/label', 'test1/label', 'test2/label'], 'DATASET_3_INTERM_F_LANDMARKS_DIR_NAME': 'AnnotationsByMD/400_senior'}

# %% [markdown]
# ## create the directory paths

# %%
metadata = []

for i in range(len(params['DATASET_3_INTERM_IMG_DIR_NAME'])):
    # create the directory paths
    img_foldername = params['DATASET_3_INTERM_IMG_DIR_NAME'][i]
    image_dir = os.path.join(
        params['INTERMEDIATE_DATA_DIRECTORY'],
        params['DATASET_3_INTERM_DIR_NAME'],
        img_foldername,
    )
    v_landmarks_foldername = params['DATASET_3_INTERM_V_LANDMARKS_DIR_NAME'][i]
    v_landmarks_dir = os.path.join(
        params['INTERMEDIATE_DATA_DIRECTORY'],
        params['DATASET_3_INTERM_DIR_NAME'],
        v_landmarks_foldername,
    )

    f_landmarks_dir = None
    if params['DATASET_3_INTERM_F_LANDMARKS_DIR_NAME'] is not None:
        f_landmarks_dir = os.path.join(
            params['INTERMEDIATE_DATA_DIRECTORY'],
            params['DATASET_3_INTERM_DIR_NAME'],
            params['DATASET_3_INTERM_F_LANDMARKS_DIR_NAME'],
        )

    # parse the directory
    image_filenames = os.listdir(image_dir)
    
    # harmonize all the images and annotations
    # create a variable showing the development set, if exists
    if len(params['DATASET_3_INTERM_IMG_DIR_NAME']) > 1:
        dev_set = img_foldername.split('/')[0]
    else:
        dev_set = None
    # Traverse the images and harmonize them one by one
    for image_filename in image_filenames:
        harmonized_id, v_landmarks_present, f_landmarks_present = harmonize_hdf5(
            image_filename=image_filename,
            image_dir=image_dir,
            v_annot_dir=v_landmarks_dir,
            f_annot_dir=f_landmarks_dir,
        )
        metadata.append(
            {
                'source_image_filename': image_filename,
                'harmonized_id': harmonized_id,
                'dataset': DATASET,
                'dev_set': dev_set,
                'v_annots_present': v_landmarks_present,
                'f_annots_present': f_landmarks_present,
            }
        )

metadata = pd.DataFrame(metadata)
# Out:
# --- v annots was not None, but, the code encountered an error!
# --- v annots was not None, but, the code encountered an error!
# --- v annots was not None, but, the code encountered an error!

# %% [markdown]
# ### write the metadata table to disk

# %%
metadata.to_hdf(
    os.path.join(params['PRIMARY_DATA_DIRECTORY'], 'metadata.hdf5'),
    key='df',
    index=False,
    mode='a',
    append=True,
    format='table',
)

# %% [markdown]
# ## sanity check some of them

# %%
i = 0
harmonized_ids = metadata.loc[metadata['dataset'] == DATASET,['harmonized_id']].to_numpy().ravel()
for harmonized_id in harmonized_ids:
    if i % 10 == 0:
        filename = harmonized_id+'.hdf5'
        image, v_landmarks, f_landmarks = read_harmonized_hdf5(
            h5py_filename=filename,
        )
        print(filename)
        print("image.shape ", image.shape)
        print("vertebrate_ids: ", v_landmarks['vertebrate_ids'])
        print("vertebral landmarks: ", v_landmarks['v_landmarks'])
        print("facial landmarks: ", f_landmarks['f_landmarks'])
        print()
    i += 1
# Out:
# a82d2ab7062a42787a171a138a62de05b2b63b0d9dfac5eb581d0bab9f3e8172.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 418, 1672],
#        [ 462, 1674],
#        [ 532, 1717],
#        [ 463, 1674]]), array([[ 411, 1710],
#        [ 387, 1844],
#        [ 444, 1853],
#        [ 512, 1880],
#        [ 523, 1754]]), array([[ 377, 1873],
#        [ 348, 2010],
#        [ 403, 2018],
#        [ 461, 2059],
#        [ 490, 1920]])]
# facial landmarks:  [[ 747  941]
#  [1319  984]
#  [1198 1195]
#  [ 534 1143]
#  [1295 1500]
#  [1224 1824]
#  [1215 1966]
#  [1158 2027]
#  [1193 2012]
#  [ 621 1709]
#  [1322 1663]
#  [1366 1696]
#  [1508 1598]
#  [1433 1821]
#  [1402 1476]
#  [1326 2030]
#  [ 875 1366]
#  [1311 1424]
#  [ 576 1251]]
#
# c46c957c51ce9834bcdb425a120aebe549ec1ad7b6093d1349094adc6cba577b.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 612, 1617],
#        [ 661, 1606],
#        [ 730, 1632],
#        [ 662, 1606]]), array([[ 620, 1646],
#        [ 605, 1767],
#        [ 661, 1759],
#        [ 725, 1792],
#        [ 726, 1670]]), array([[ 614, 1793],
#        [ 588, 1919],
#        [ 648, 1919],
#        [ 716, 1942],
#        [ 719, 1824]])]
# facial landmarks:  [[ 754  924]
#  [1304  732]
#  [1244 1032]
#  [ 593 1136]
#  [1392 1328]
#  [1304 1636]
#  [1288 1763]
#  [1244 1826]
#  [1277 1801]
#  [ 766 1552]
#  [1381 1480]
#  [1455 1509]
#  [1566 1392]
#  [1495 1608]
#  [1495 1261]
#  [1379 1842]
#  [ 986 1279]
#  [1400 1231]
#  [ 692 1212]]
#
# 0974665e0f3a8ec77d4320f2a8d2a42b67f36f1faf7ed3ecf86bdba7a14d6f9b.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 588, 1832],
#        [ 633, 1820],
#        [ 693, 1856],
#        [ 632, 1819]]), array([[ 589, 1859],
#        [ 587, 1976],
#        [ 647, 1965],
#        [ 694, 2010],
#        [ 702, 1898]]), array([[ 588, 2001],
#        [ 574, 2111],
#        [ 634, 2111],
#        [ 676, 2148],
#        [ 696, 2049]])]
# facial landmarks:  [[ 816 1067]
#  [1376  962]
#  [1293 1214]
#  [ 615 1288]
#  [1455 1489]
#  [1473 1798]
#  [1494 1934]
#  [1442 2006]
#  [1476 1981]
#  [ 828 1783]
#  [1504 1648]
#  [1519 1649]
#  [1621 1567]
#  [1640 1698]
#  [1549 1446]
#  [1523 2018]
#  [ 999 1451]
#  [1451 1417]
#  [ 690 1395]]
#
# 0f0fea0b7b3fe131ec59fc7748951c9c15632170736f0b6e7d0e6478947261a2.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 566, 1757],
#        [ 603, 1752],
#        [ 683, 1798],
#        [ 604, 1753]]), array([[ 567, 1783],
#        [ 548, 1909],
#        [ 585, 1904],
#        [ 678, 1945],
#        [ 685, 1826]]), array([[ 552, 1937],
#        [ 536, 2063],
#        [ 586, 2056],
#        [ 671, 2094],
#        [ 673, 1976]])]
# facial landmarks:  [[ 883 1063]
#  [1491 1006]
#  [1369 1255]
#  [ 631 1222]
#  [1505 1523]
#  [1444 1874]
#  [1427 1997]
#  [1375 2073]
#  [1408 2043]
#  [ 775 1818]
#  [1538 1731]
#  [1549 1730]
#  [1692 1660]
#  [1651 1871]
#  [1646 1494]
#  [1521 2086]
#  [1035 1430]
#  [1522 1478]
#  [ 732 1346]]
#
# 04f4b830e3a1150f3f91561d6855217d534971077d3f753d887199b26734f63b.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 580, 1789],
#        [ 629, 1782],
#        [ 704, 1830],
#        [ 630, 1782]]), array([[ 577, 1819],
#        [ 553, 1966],
#        [ 601, 1962],
#        [ 686, 2001],
#        [ 703, 1867]]), array([[ 547, 1998],
#        [ 549, 2148],
#        [ 588, 2130],
#        [ 674, 2161],
#        [ 673, 2028]])]
# facial landmarks:  [[ 875  972]
#  [1470  932]
#  [1313 1188]
#  [ 658 1220]
#  [1436 1511]
#  [1509 1883]
#  [1526 2016]
#  [1435 2111]
#  [1500 2076]
#  [ 842 1844]
#  [1512 1715]
#  [1505 1686]
#  [1658 1648]
#  [1659 1789]
#  [1551 1500]
#  [1618 2091]
#  [1055 1404]
#  [1436 1441]
#  [ 729 1349]]
#
# fd2451f8434278e15ce92ebecd75c5dc221a19e8294f098b34db710e9e1c5f29.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 479, 1627],
#        [ 514, 1629],
#        [ 576, 1663],
#        [ 515, 1631]]), array([[ 462, 1671],
#        [ 451, 1748],
#        [ 492, 1751],
#        [ 565, 1772],
#        [ 560, 1704]]), array([[ 447, 1794],
#        [ 442, 1870],
#        [ 485, 1871],
#        [ 556, 1879],
#        [ 553, 1818]])]
# facial landmarks:  [[ 807  954]
#  [1372  968]
#  [1226 1210]
#  [ 623 1157]
#  [1299 1474]
#  [1272 1746]
#  [1252 1851]
#  [1192 1906]
#  [1229 1891]
#  [ 750 1662]
#  [1312 1624]
#  [1318 1605]
#  [1423 1530]
#  [1401 1706]
#  [1373 1431]
#  [1323 1925]
#  [ 941 1352]
#  [1341 1397]
#  [ 642 1311]]
#
# 10cb696f9afd5afe32f686c217583d88cf883ce4b9e08596a76fc03099a380c0.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 560, 1744],
#        [ 598, 1737],
#        [ 675, 1777],
#        [ 597, 1737]]), array([[ 561, 1774],
#        [ 547, 1883],
#        [ 586, 1880],
#        [ 656, 1930],
#        [ 671, 1835]]), array([[ 537, 1907],
#        [ 497, 2010],
#        [ 547, 2017],
#        [ 592, 2070],
#        [ 636, 1985]])]
# facial landmarks:  [[ 858 1063]
#  [1436 1002]
#  [1293 1261]
#  [ 630 1266]
#  [1402 1592]
#  [1437 1858]
#  [1443 1937]
#  [1390 1996]
#  [1424 1972]
#  [ 857 1735]
#  [1468 1703]
#  [1387 1737]
#  [1589 1686]
#  [1619 1831]
#  [1524 1577]
#  [1497 2066]
#  [ 994 1465]
#  [1420 1536]
#  [ 683 1303]]
#
# b61c8ded72be81abe0719ffa3cfc5f50bf913a9b35518ce5a8b9bfe1c16f1651.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 404, 1800],
#        [ 465, 1793],
#        [ 534, 1840],
#        [ 465, 1792]]), array([[ 400, 1837],
#        [ 362, 1973],
#        [ 420, 1969],
#        [ 493, 2029],
#        [ 523, 1884]]), array([[ 355, 1999],
#        [ 315, 2133],
#        [ 376, 2136],
#        [ 445, 2199],
#        [ 479, 2076]])]
# facial landmarks:  [[ 819 1084]
#  [1457 1105]
#  [1282 1337]
#  [ 563 1232]
#  [1359 1625]
#  [1373 1980]
#  [1408 2097]
#  [1343 2160]
#  [1387 2143]
#  [ 712 1846]
#  [1411 1805]
#  [1388 1816]
#  [1568 1782]
#  [1567 1957]
#  [1498 1670]
#  [1467 2192]
#  [ 947 1530]
#  [1393 1602]
#  [ 604 1302]]
#
# 130971b81b05f7031774b506aa6eaecd9e56466657af4af1655a7bd917cb3772.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 487, 1825],
#        [ 527, 1812],
#        [ 634, 1840],
#        [ 527, 1812]]), array([[ 489, 1852],
#        [ 487, 2001],
#        [ 542, 1990],
#        [ 648, 2014],
#        [ 639, 1886]]), array([[ 492, 2036],
#        [ 489, 2185],
#        [ 538, 2172],
#        [ 641, 2202],
#        [ 641, 2064]])]
# facial landmarks:  [[ 799 1039]
#  [1469  955]
#  [1264 1225]
#  [ 623 1204]
#  [1447 1571]
#  [1510 1900]
#  [1528 2063]
#  [1464 2158]
#  [1511 2129]
#  [ 820 1864]
#  [1552 1739]
#  [1528 1730]
#  [1667 1648]
#  [1692 1841]
#  [1574 1536]
#  [1644 2167]
#  [ 983 1445]
#  [1441 1487]
#  [ 662 1353]]
#
# acc814b4dfdeeb2983900fe69fbc8f236135e3006d1ece5c0f25db70cd8aa846.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 578, 1745],
#        [ 642, 1733],
#        [ 723, 1765],
#        [ 644, 1733]]), array([[ 577, 1760],
#        [ 575, 1921],
#        [ 627, 1904],
#        [ 726, 1936],
#        [ 720, 1803]]), array([[ 572, 1948],
#        [ 564, 2079],
#        [ 637, 2082],
#        [ 726, 2107],
#        [ 722, 1992]])]
# facial landmarks:  [[ 795 1044]
#  [1402  908]
#  [1276 1172]
#  [ 648 1205]
#  [1455 1471]
#  [1409 1810]
#  [1407 1958]
#  [1342 2027]
#  [1389 2007]
#  [ 770 1792]
#  [1483 1628]
#  [1548 1655]
#  [1639 1566]
#  [1608 1756]
#  [1580 1441]
#  [1483 1991]
#  [1003 1427]
#  [1460 1394]
#  [ 675 1371]]
#
# d82c56b49121e0669ed4ddbe893338c9e5af184b9fda933865226608e7de3a3e.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 438, 1698],
#        [ 486, 1694],
#        [ 551, 1724],
#        [ 487, 1693]]), array([[ 427, 1726],
#        [ 410, 1848],
#        [ 461, 1842],
#        [ 539, 1864],
#        [ 548, 1759]]), array([[ 401, 1882],
#        [ 406, 2000],
#        [ 452, 1997],
#        [ 532, 2011],
#        [ 533, 1901]])]
# facial landmarks:  [[ 759 1027]
#  [1326  978]
#  [1243 1212]
#  [ 590 1205]
#  [1345 1557]
#  [1244 1877]
#  [1207 1990]
#  [1144 2059]
#  [1184 2033]
#  [ 657 1738]
#  [1316 1722]
#  [1339 1739]
#  [1496 1625]
#  [1427 1853]
#  [1419 1516]
#  [1281 2110]
#  [ 905 1429]
#  [1349 1452]
#  [ 606 1339]]
#
# 619107204049ab953b7d8603045f57db4633dbd9c71678334c1fc95b3711a70e.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 489, 1815],
#        [ 522, 1804],
#        [ 599, 1846],
#        [ 522, 1805]]), array([[ 484, 1837],
#        [ 467, 1961],
#        [ 520, 1961],
#        [ 584, 1999],
#        [ 600, 1894]]), array([[ 470, 1978],
#        [ 439, 2112],
#        [ 509, 2112],
#        [ 572, 2145],
#        [ 582, 2039]])]
# facial landmarks:  [[ 753 1088]
#  [1322 1029]
#  [1185 1290]
#  [ 562 1252]
#  [1372 1587]
#  [1312 1887]
#  [1296 2010]
#  [1263 2075]
#  [1289 2049]
#  [ 629 1766]
#  [1379 1725]
#  [1412 1747]
#  [1511 1647]
#  [1469 1837]
#  [1469 1524]
#  [1380 2071]
#  [ 924 1513]
#  [1341 1492]
#  [ 638 1309]]
#
# d32f84a67e276cccf0c3acda4afb32578e7629d595ee605b44a96e8f5ecb318a.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 394, 1758],
#        [ 433, 1765],
#        [ 497, 1816],
#        [ 435, 1766]]), array([[ 380, 1793],
#        [ 328, 1927],
#        [ 370, 1928],
#        [ 436, 1979],
#        [ 483, 1853]]), array([[ 311, 1960],
#        [ 267, 2086],
#        [ 312, 2090],
#        [ 372, 2138],
#        [ 419, 2025]])]
# facial landmarks:  [[ 797  995]
#  [1369 1053]
#  [1231 1328]
#  [ 598 1190]
#  [1260 1631]
#  [1148 1992]
#  [1116 2069]
#  [1046 2124]
#  [1086 2105]
#  [ 649 1765]
#  [1267 1848]
#  [1273 1840]
#  [1473 1773]
#  [1379 2012]
#  [1421 1660]
#  [1206 2190]
#  [ 858 1473]
#  [1305 1592]
#  [ 643 1309]]
#
# 220d79b335ee90c5c9fdbb11bc4170703785938d0be93699722c07fb7afd0649.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 589, 1680],
#        [ 648, 1682],
#        [ 707, 1708],
#        [ 648, 1681]]), array([[ 595, 1695],
#        [ 559, 1820],
#        [ 598, 1816],
#        [ 681, 1850],
#        [ 699, 1735]]), array([[ 557, 1847],
#        [ 537, 1969],
#        [ 604, 1965],
#        [ 660, 1999],
#        [ 666, 1887]])]
# facial landmarks:  [[ 845  976]
#  [1457  913]
#  [1307 1180]
#  [ 627 1206]
#  [1458 1494]
#  [1408 1785]
#  [1383 1930]
#  [1317 2027]
#  [1365 1989]
#  [ 783 1744]
#  [1493 1638]
#  [1517 1664]
#  [1620 1598]
#  [1589 1741]
#  [1561 1444]
#  [1519 2001]
#  [1021 1372]
#  [1465 1426]
#  [ 703 1347]]
#
# e4ce79f6609e15dda8f0812fc9588f926167e4d651860febc527ba6cc33fb611.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 515, 1717],
#        [ 555, 1713],
#        [ 640, 1732],
#        [ 555, 1714]]), array([[ 518, 1752],
#        [ 518, 1832],
#        [ 555, 1834],
#        [ 647, 1849],
#        [ 644, 1790]]), array([[ 520, 1873],
#        [ 518, 1963],
#        [ 575, 1967],
#        [ 642, 1973],
#        [ 645, 1918]])]
# facial landmarks:  [[ 782 1003]
#  [1369  936]
#  [1236 1200]
#  [ 570 1178]
#  [1373 1448]
#  [1342 1814]
#  [1327 1912]
#  [1247 1979]
#  [1302 1957]
#  [ 662 1707]
#  [1434 1629]
#  [1456 1632]
#  [1569 1566]
#  [1539 1767]
#  [1487 1420]
#  [1429 2003]
#  [ 958 1401]
#  [1420 1371]
#  [ 613 1239]]
#
# 9d822789d09b31eadbeeeb9ea45c0c4d9d5fb12d513822618ddea02e46bbaa38.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 505, 1658],
#        [ 564, 1658],
#        [ 636, 1693]]), array([[ 490, 1823],
#        [ 536, 1818],
#        [ 616, 1859],
#        [ 624, 1727],
#        [ 497, 1685]]), array([[ 468, 1976],
#        [ 554, 1985],
#        [ 596, 2019],
#        [ 601, 1892],
#        [ 473, 1861]])]
# facial landmarks:  [[ 808 1000]
#  [1448  986]
#  [1305 1267]
#  [ 585 1182]
#  [1412 1529]
#  [1395 1915]
#  [1402 2052]
#  [1358 2098]
#  [1386 2087]
#  [ 698 1726]
#  [1465 1739]
#  [1488 1748]
#  [1669 1656]
#  [1636 1901]
#  [1554 1558]
#  [1526 2123]
#  [ 951 1402]
#  [1437 1475]
#  [ 648 1270]]
#
# 946f955ca3874214e675c92be69de857faaa0b726262e841a0bf94d63cea11bd.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 526, 1645],
#        [ 595, 1645],
#        [ 639, 1687]]), array([[ 498, 1795],
#        [ 600, 1809],
#        [ 622, 1835],
#        [ 637, 1718],
#        [ 525, 1675]]), array([[ 467, 1944],
#        [ 537, 1943],
#        [ 595, 1980],
#        [ 612, 1861],
#        [ 498, 1817]])]
# facial landmarks:  [[ 804  916]
#  [1362  852]
#  [1232 1089]
#  [ 603 1148]
#  [1415 1392]
#  [1359 1681]
#  [1364 1836]
#  [1311 1891]
#  [1346 1876]
#  [ 686 1626]
#  [1406 1543]
#  [1453 1559]
#  [1530 1452]
#  [1510 1637]
#  [1484 1326]
#  [1459 1861]
#  [ 963 1327]
#  [1423 1277]
#  [ 691 1202]]
#
# 35a9d45ce005fa68b8c3a44e6dc7a76d20892d07554402aa52497f6eb413314b.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 540, 1776],
#        [ 588, 1772],
#        [ 651, 1803]]), array([[ 525, 1904],
#        [ 607, 1911],
#        [ 632, 1937],
#        [ 631, 1833],
#        [ 530, 1790]]), array([[ 508, 2028],
#        [ 574, 2032],
#        [ 622, 2059],
#        [ 618, 1953],
#        [ 517, 1918]])]
# facial landmarks:  [[ 860  986]
#  [1386  953]
#  [1307 1217]
#  [ 652 1222]
#  [1412 1485]
#  [1342 1757]
#  [1320 1889]
#  [1267 1944]
#  [1307 1928]
#  [ 719 1677]
#  [1406 1645]
#  [1479 1657]
#  [1573 1553]
#  [1531 1777]
#  [1522 1469]
#  [1424 1923]
#  [ 993 1436]
#  [1419 1436]
#  [ 671 1351]]
#
# 73b6ef3f64ad908001876dad18af9a569a806dcf9f1f32bdbf59f2b8690b00d4.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 477, 1655],
#        [ 551, 1656],
#        [ 597, 1700]]), array([[ 446, 1820],
#        [ 520, 1817],
#        [ 562, 1859],
#        [ 582, 1720],
#        [ 477, 1678]]), array([[ 407, 1970],
#        [ 479, 1970],
#        [ 528, 2020],
#        [ 551, 1881],
#        [ 439, 1835]])]
# facial landmarks:  [[ 806  947]
#  [1369  932]
#  [1224 1200]
#  [ 602 1138]
#  [1281 1535]
#  [1290 1860]
#  [1287 2008]
#  [1226 2051]
#  [1269 2051]
#  [ 736 1691]
#  [1340 1694]
#  [1287 1716]
#  [1441 1627]
#  [1466 1827]
#  [1370 1502]
#  [1382 2066]
#  [ 883 1374]
#  [1253 1417]
#  [ 672 1255]]
#
# 4402ee2e9e9e94b7107cb5b681b363116c7f88388e08b4464aa23bbd18f120db.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 443, 1754],
#        [ 493, 1762],
#        [ 557, 1829]]), array([[ 390, 1900],
#        [ 445, 1903],
#        [ 517, 1969],
#        [ 549, 1843],
#        [ 433, 1782]]), array([[ 346, 2056],
#        [ 433, 2071],
#        [ 477, 2126],
#        [ 508, 1990],
#        [ 376, 1940]])]
# facial landmarks:  [[ 798 1106]
#  [1449 1030]
#  [1296 1275]
#  [ 626 1214]
#  [1407 1596]
#  [1345 1916]
#  [1213 2120]
#  [1147 2143]
#  [1187 2139]
#  [ 665 1773]
#  [1441 1817]
#  [1460 1813]
#  [1591 1750]
#  [1516 1945]
#  [1561 1599]
#  [1335 2147]
#  [ 969 1487]
#  [1433 1535]
#  [ 686 1373]]
#
# 2611c9f8bb7eebcd36db9689d4e75bb2515d5d19edec6a113ca882cbe7a10ed6.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 475, 1809],
#        [ 528, 1808],
#        [ 611, 1862]]), array([[ 437, 1974],
#        [ 529, 1978],
#        [ 584, 2027],
#        [ 611, 1905],
#        [ 475, 1842]]), array([[ 399, 2133],
#        [ 481, 2138],
#        [ 548, 2199],
#        [ 579, 2081],
#        [ 440, 2006]])]
# facial landmarks:  [[ 810 1059]
#  [1424 1024]
#  [1278 1266]
#  [ 626 1215]
#  [1429 1550]
#  [1399 1865]
#  [1373 2032]
#  [1334 2083]
#  [1359 2063]
#  [ 766 1852]
#  [1461 1714]
#  [1427 1739]
#  [1582 1685]
#  [1605 1815]
#  [1509 1554]
#  [1470 2072]
#  [ 949 1445]
#  [1351 1484]
#  [ 656 1360]]
#
# f4962699fffbd6cb6ce0921e036ed78b87cf28248ec2ae45ad94151fb4fda483.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  None
# vertebral landmarks:  None
# facial landmarks:  [[ 852 1133]
#  [1384 1145]
#  [1301 1360]
#  [ 597 1268]
#  [1385 1704]
#  [1441 2079]
#  [1466 2197]
#  [1414 2299]
#  [1456 2251]
#  [ 741 1837]
#  [1442 1904]
#  [1413 1909]
#  [1597 1856]
#  [1597 1972]
#  [1544 1709]
#  [1579 2297]
#  [ 993 1575]
#  [1399 1625]
#  [ 646 1371]]
#
# f72251d35242d6d1e42aa38e45c8cdcb00ae31d5e3e70e67dccd567c190270fb.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 586, 1780],
#        [ 642, 1762],
#        [ 705, 1791]]), array([[ 583, 1920],
#        [ 623, 1904],
#        [ 706, 1935],
#        [ 696, 1825],
#        [ 584, 1810]]), array([[ 589, 2070],
#        [ 633, 2051],
#        [ 722, 2070],
#        [ 709, 1969],
#        [ 579, 1949]])]
# facial landmarks:  [[ 748 1036]
#  [1336  940]
#  [1271 1178]
#  [ 554 1275]
#  [1391 1474]
#  [1365 1764]
#  [1357 1896]
#  [1321 1957]
#  [1349 1935]
#  [ 732 1710]
#  [1414 1621]
#  [1446 1651]
#  [1546 1550]
#  [1519 1718]
#  [1490 1427]
#  [1421 1946]
#  [ 942 1448]
#  [1391 1399]
#  [ 661 1341]]
#
# 3fb38b4761794bc7c2a6918ec8d5b518740a0765ddbc9ced16bf0a582707cc25.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  None
# vertebral landmarks:  None
# facial landmarks:  [[ 820 1038]
#  [1380 1067]
#  [1251 1305]
#  [ 564 1210]
#  [1291 1583]
#  [1249 1876]
#  [1221 2005]
#  [1147 2067]
#  [1194 2047]
#  [ 656 1700]
#  [1310 1744]
#  [1333 1770]
#  [1455 1715]
#  [1423 1850]
#  [1455 1599]
#  [1261 2094]
#  [ 911 1457]
#  [1334 1557]
#  [ 637 1305]]
#
# 00583d20b08229643e9bd82e14f2e8b6b3581d8f7fb7bdbe143c5df11979f00a.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 447, 1773],
#        [ 489, 1775],
#        [ 551, 1831]]), array([[ 403, 1903],
#        [ 456, 1909],
#        [ 515, 1957],
#        [ 543, 1856],
#        [ 437, 1797]]), array([[ 365, 2044],
#        [ 418, 2040],
#        [ 491, 2086],
#        [ 504, 1985],
#        [ 394, 1931]])]
# facial landmarks:  [[ 860 1121]
#  [1402 1132]
#  [1285 1376]
#  [ 602 1279]
#  [1350 1647]
#  [1364 1935]
#  [1374 2027]
#  [1338 2088]
#  [1371 2071]
#  [ 708 1740]
#  [1361 1797]
#  [1378 1797]
#  [1480 1717]
#  [1478 1817]
#  [1445 1643]
#  [1468 2073]
#  [ 949 1527]
#  [1377 1597]
#  [ 677 1346]]
#
# efa051ac17fa22d450739d814409a1f9b0eaef8731ef63c9175cb91bde1b1fa2.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 509, 1842],
#        [ 561, 1837],
#        [ 624, 1893]]), array([[ 457, 2004],
#        [ 512, 2002],
#        [ 589, 2061],
#        [ 612, 1920],
#        [ 495, 1867]]), array([[ 409, 2164],
#        [ 505, 2185],
#        [ 542, 2229],
#        [ 573, 2088],
#        [ 443, 2025]])]
# facial landmarks:  [[ 862 1098]
#  [1413 1041]
#  [1329 1281]
#  [ 597 1284]
#  [1410 1645]
#  [1471 1985]
#  [1440 2182]
#  [1372 2215]
#  [1410 2213]
#  [ 722 1803]
#  [1483 1816]
#  [1454 1821]
#  [1577 1712]
#  [1612 1884]
#  [1547 1590]
#  [1519 2176]
#  [ 999 1518]
#  [1441 1530]
#  [ 683 1413]]
#
# 5c92d2e101df8a80baf66d1d624b454c9647ef19ccf8b1304300909a20ab4e37.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 455, 1699],
#        [ 502, 1707],
#        [ 562, 1765]]), array([[ 405, 1849],
#        [ 436, 1846],
#        [ 519, 1907],
#        [ 551, 1781],
#        [ 437, 1738]]), array([[ 355, 1989],
#        [ 416, 1999],
#        [ 473, 2052],
#        [ 504, 1931],
#        [ 391, 1877]])]
# facial landmarks:  [[ 765 1026]
#  [1320 1012]
#  [1236 1226]
#  [ 563 1216]
#  [1371 1553]
#  [1340 1870]
#  [1294 2048]
#  [1209 2092]
#  [1259 2090]
#  [ 684 1689]
#  [1410 1716]
#  [1455 1731]
#  [1534 1639]
#  [1500 1844]
#  [1439 1497]
#  [1414 2094]
#  [ 936 1415]
#  [1361 1447]
#  [ 646 1313]]
#
# 49c4402c804bda01f76b3742414eeeac2b726eaa3e42f15770e240513608c012.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 516, 1766],
#        [ 554, 1754],
#        [ 651, 1794]]), array([[ 498, 1934],
#        [ 533, 1928],
#        [ 636, 1958],
#        [ 642, 1825],
#        [ 506, 1789]]), array([[ 497, 2099],
#        [ 548, 2094],
#        [ 625, 2127],
#        [ 629, 2002],
#        [ 489, 1963]])]
# facial landmarks:  [[ 849 1090]
#  [1472 1102]
#  [1298 1312]
#  [ 633 1215]
#  [1357 1627]
#  [1358 1919]
#  [1378 2017]
#  [1335 2094]
#  [1368 2064]
#  [ 689 1846]
#  [1369 1764]
#  [1363 1763]
#  [1514 1732]
#  [1510 1865]
#  [1484 1654]
#  [1469 2107]
#  [ 947 1491]
#  [1385 1576]
#  [ 666 1366]]
#
# c490a6a831f74caedc894a5a02579b6a2bcf466d0fc9c0c4aa9f2a13daf0aefd.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 491, 1680],
#        [ 541, 1680],
#        [ 597, 1727]]), array([[ 443, 1816],
#        [ 490, 1821],
#        [ 552, 1875],
#        [ 580, 1775],
#        [ 478, 1705]]), array([[ 392, 1962],
#        [ 437, 1961],
#        [ 501, 2000],
#        [ 533, 1903],
#        [ 426, 1835]])]
# facial landmarks:  [[ 778 1030]
#  [1383 1030]
#  [1255 1279]
#  [ 575 1181]
#  [1254 1588]
#  [1167 1906]
#  [1104 2085]
#  [1045 2125]
#  [1084 2118]
#  [ 604 1663]
#  [1249 1780]
#  [1267 1808]
#  [1390 1767]
#  [1340 1904]
#  [1396 1595]
#  [1212 2122]
#  [ 884 1453]
#  [1299 1508]
#  [ 638 1294]]
#
# ec5211bd6aad0d5c6fa3c862602e99b7b36ddca050a1b8cb76fef169fee2dfff.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 505, 1624],
#        [ 557, 1609],
#        [ 615, 1640]]), array([[ 500, 1774],
#        [ 566, 1767],
#        [ 614, 1800],
#        [ 607, 1667],
#        [ 501, 1642]]), array([[ 483, 1929],
#        [ 542, 1924],
#        [ 587, 1956],
#        [ 598, 1834],
#        [ 496, 1803]])]
# facial landmarks:  [[ 776  992]
#  [1343  931]
#  [1217 1181]
#  [ 581 1148]
#  [1266 1492]
#  [1306 1813]
#  [1311 1947]
#  [1267 2013]
#  [1298 1989]
#  [ 690 1661]
#  [1351 1675]
#  [1320 1663]
#  [1426 1574]
#  [1439 1772]
#  [1398 1476]
#  [1366 2030]
#  [ 911 1407]
#  [1296 1430]
#  [ 649 1259]]
#
# 3f5caace50f0304bafc4e8533ca125ab6b355131b383b60c82e116e932b60964.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 539, 1785],
#        [ 596, 1795],
#        [ 665, 1814]]), array([[ 536, 1920],
#        [ 593, 1920],
#        [ 658, 1926],
#        [ 649, 1869],
#        [ 529, 1817]]), array([[ 544, 2051],
#        [ 565, 2044],
#        [ 665, 2044],
#        [ 652, 1982],
#        [ 532, 1959]])]
# facial landmarks:  [[ 837 1107]
#  [1405 1059]
#  [1315 1283]
#  [ 624 1279]
#  [1396 1618]
#  [1303 1960]
#  [1299 2035]
#  [1255 2092]
#  [1284 2074]
#  [ 713 1759]
#  [1410 1801]
#  [1449 1795]
#  [1533 1639]
#  [1475 1925]
#  [1460 1557]
#  [1408 2016]
#  [ 999 1510]
#  [1409 1539]
#  [ 709 1401]]
#
# 6ea0bdcc7080b3760fcdf8bd03fe955b10bfdf8abca5f5d02458b35a8c90ec6e.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  None
# vertebral landmarks:  None
# facial landmarks:  [[ 873 1045]
#  [1474 1026]
#  [1363 1262]
#  [ 627 1180]
#  [1425 1556]
#  [1380 1960]
#  [1385 2050]
#  [1329 2121]
#  [1367 2100]
#  [ 735 1849]
#  [1447 1735]
#  [1472 1754]
#  [1590 1711]
#  [1538 1891]
#  [1533 1574]
#  [1524 2125]
#  [1014 1422]
#  [1452 1511]
#  [ 681 1372]]
#
# 55a25037120878fe3dd70e98b4e3ab954b264cc93d1c208a473fd5970edf0d7f.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 420, 1643],
#        [ 473, 1640],
#        [ 542, 1683]]), array([[ 393, 1824],
#        [ 475, 1824],
#        [ 522, 1850],
#        [ 529, 1712],
#        [ 410, 1674]]), array([[ 385, 1997],
#        [ 484, 1997],
#        [ 511, 2022],
#        [ 509, 1879],
#        [ 386, 1856]])]
# facial landmarks:  [[ 707  942]
#  [1335  825]
#  [1233 1054]
#  [ 513 1105]
#  [1311 1393]
#  [1226 1860]
#  [1218 1953]
#  [1142 2019]
#  [1179 1999]
#  [ 615 1671]
#  [1319 1646]
#  [1335 1641]
#  [1512 1476]
#  [1444 1760]
#  [1447 1373]
#  [1361 1877]
#  [ 898 1322]
#  [1373 1333]
#  [ 607 1227]]
#
# 262bd76e615c69c9a162dbdf38902c935cbb84e7db8b3d2c59b46ed7a38d18fb.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 516, 1688],
#        [ 557, 1680],
#        [ 632, 1727]]), array([[ 487, 1824],
#        [ 556, 1824],
#        [ 609, 1859],
#        [ 621, 1744],
#        [ 512, 1707]]), array([[ 469, 1967],
#        [ 557, 1967],
#        [ 590, 1992],
#        [ 594, 1877],
#        [ 481, 1849]])]
# facial landmarks:  [[ 761 1042]
#  [1334  908]
#  [1259 1157]
#  [ 597 1199]
#  [1377 1418]
#  [1317 1793]
#  [1311 1897]
#  [1260 1968]
#  [1291 1943]
#  [ 728 1650]
#  [1401 1594]
#  [1469 1637]
#  [1533 1481]
#  [1509 1741]
#  [1476 1382]
#  [1442 1818]
#  [ 980 1396]
#  [1407 1358]
#  [ 690 1308]]
#
# 41b06fe269bbab43b327bd52e3cad3da9b78a0f23775ffa76d1eee07d2a294c0.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 650, 1754],
#        [ 704, 1746],
#        [ 790, 1769],
#        [ 705, 1747]]), array([[ 645, 1782],
#        [ 644, 1922],
#        [ 700, 1910],
#        [ 784, 1927],
#        [ 784, 1820]]), array([[ 643, 1944],
#        [ 635, 2079],
#        [ 700, 2067],
#        [ 784, 2089],
#        [ 786, 1980]])]
# facial landmarks:  [[ 857  989]
#  [1510  960]
#  [1399 1145]
#  [ 597 1213]
#  [1527 1496]
#  [1492 1902]
#  [1486 1985]
#  [1430 2057]
#  [1471 2034]
#  [ 816 1769]
#  [1576 1690]
#  [1598 1708]
#  [1716 1585]
#  [1678 1853]
#  [1633 1475]
#  [1616 2030]
#  [1067 1414]
#  [1538 1428]
#  [ 684 1355]]
#
# ed122608e29391b4e14c65473b37ca273082fe17354df8c10fdd9999cf035ed9.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  None
# vertebral landmarks:  None
# facial landmarks:  [[ 762 1037]
#  [1234  911]
#  [1161 1083]
#  [ 595 1223]
#  [1296 1344]
#  [1269 1679]
#  [1262 1753]
#  [1209 1809]
#  [1241 1793]
#  [ 757 1618]
#  [1330 1513]
#  [1367 1499]
#  [1450 1376]
#  [1431 1602]
#  [1395 1305]
#  [1362 1721]
#  [ 957 1336]
#  [1276 1277]
#  [ 671 1277]]
#
# 9e5741293c06051ec4aaf5e4e1fe93f9899404442e31736eda08535fc554c708.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 513, 1801],
#        [ 572, 1799],
#        [ 635, 1859]]), array([[ 468, 1959],
#        [ 515, 1951],
#        [ 607, 2012],
#        [ 623, 1882],
#        [ 498, 1825]]), array([[ 453, 2124],
#        [ 551, 2129],
#        [ 590, 2166],
#        [ 598, 2041],
#        [ 459, 1992]])]
# facial landmarks:  [[ 793 1039]
#  [1441  974]
#  [1306 1170]
#  [ 613 1244]
#  [1419 1559]
#  [1332 1893]
#  [1352 2004]
#  [1290 2074]
#  [1331 2051]
#  [ 723 1769]
#  [1414 1714]
#  [1454 1769]
#  [1598 1649]
#  [1544 1873]
#  [1546 1528]
#  [1459 1990]
#  [1036 1470]
#  [1463 1491]
#  [ 710 1349]]
#
# 8ae7bbf874db6d42cc2f6cf4097fdd1beb7e8fed20d8d6bd3cab35d4a7aec5d0.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 481, 1683],
#        [ 562, 1689],
#        [ 592, 1727]]), array([[ 449, 1815],
#        [ 512, 1816],
#        [ 563, 1858],
#        [ 580, 1747],
#        [ 473, 1706]]), array([[ 417, 1950],
#        [ 474, 1949],
#        [ 537, 1989],
#        [ 552, 1889],
#        [ 432, 1843]])]
# facial landmarks:  [[ 795 1001]
#  [1418  919]
#  [1337 1146]
#  [ 580 1198]
#  [1395 1483]
#  [1386 1888]
#  [1404 1977]
#  [1354 2046]
#  [1393 2018]
#  [ 728 1675]
#  [1454 1662]
#  [1479 1679]
#  [1586 1532]
#  [1582 1759]
#  [1534 1451]
#  [1528 1933]
#  [ 985 1424]
#  [1427 1413]
#  [ 665 1286]]
#
# 49c01013fd2c6d7d39fc9aaa00b5ff2999045bf150278bb6050a62ba41af2a5a.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 534, 1784],
#        [ 585, 1776],
#        [ 655, 1820],
#        [ 585, 1777]]), array([[ 540, 1820],
#        [ 522, 1939],
#        [ 575, 1937],
#        [ 632, 1980],
#        [ 650, 1852]]), array([[ 518, 1971],
#        [ 482, 2102],
#        [ 525, 2103],
#        [ 590, 2142],
#        [ 623, 2021]])]
# facial landmarks:  [[ 834 1039]
#  [1414  969]
#  [1306 1231]
#  [ 548 1215]
#  [1406 1548]
#  [1439 1887]
#  [1458 1984]
#  [1382 2065]
#  [1426 2037]
#  [ 801 1771]
#  [1481 1704]
#  [1449 1726]
#  [1569 1643]
#  [1600 1792]
#  [1514 1548]
#  [1550 1972]
#  [ 978 1461]
#  [1423 1489]
#  [ 648 1340]]
#
# 199bab740bfea5a63a0423645c43de38559b2e6aad4841e103bd0c6a2dbf6a2d.hdf5
# image.shape  (2400, 1935, 3)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 585, 1787],
#        [ 645, 1789],
#        [ 697, 1827]]), array([[ 537, 1948],
#        [ 607, 1957],
#        [ 661, 1999],
#        [ 681, 1853],
#        [ 584, 1809]]), array([[ 505, 2107],
#        [ 583, 2115],
#        [ 642, 2158],
#        [ 648, 2033],
#        [ 530, 1979]])]
# facial landmarks:  [[ 825 1020]
#  [1441  887]
#  [1323 1139]
#  [ 608 1264]
#  [1449 1475]
#  [1398 1820]
#  [1416 1918]
#  [1356 1989]
#  [1400 1961]
#  [ 770 1755]
#  [1474 1634]
#  [1483 1631]
#  [1618 1530]
#  [1577 1766]
#  [1578 1471]
#  [1529 1908]
#  [1030 1410]
#  [1529 1433]
#  [ 695 1351]]

# %%
metadata_table = pd.read_hdf(
    os.path.join(params['PRIMARY_DATA_DIRECTORY'], 'metadata.hdf5'),
    key='df',
)

# %%
metadata_table.head()
# Out:
#   source_image_filename                                      harmonized_id  \
# 0                45.jpg  71657ae53721e50ca772d387bd284b4dd58247893bdf4a...
# 1                92.jpg  9b252d975480242e836e274ae0e6204e84a7f0f524666c...
# 2                43.jpg  5ea321c4f7f4aa923eb7a41f73f356a9bb3162da92a632...
# 3                 7.jpg  4d97e213be2aeabc3e45d9d36eb0a82df8b48d93f9ee6a...
# 4               121.jpg  b0a2bcc695bf95ab5e88953a753b33446930251b80cced...
#
#      dataset dev_set  v_annots_present  f_annots_present
# 0  dataset_1     NaN              True             False
# 1  dataset_1     NaN              True             False
# 2  dataset_1     NaN              True             False
# 3  dataset_1     NaN              True             False
# 4  dataset_1     NaN              True             False

# %%
metadata_table.shape
# Out:
# (621, 6)

# %%
metadata_table.describe()
# Out:
#        source_image_filename  \
# count                    621
# unique                   621
# top                   45.jpg
# freq                       1
#
#                                             harmonized_id    dataset  \
# count                                                 621        621
# unique                                                621          3
# top     71657ae53721e50ca772d387bd284b4dd58247893bdf4a...  dataset_3
# freq                                                    1        400
#
#          dev_set v_annots_present f_annots_present
# count        400              621              621
# unique         3                2                2
# top     training             True             True
# freq         150              578              400
