# %%
DATASET = "dataset_1"

# %% [markdown]
# # Introduction and objective
#
# In this notebooks we would like to read the image and annotations data of dataset 1 and save them into a high performance data structure which allows fast write/read at the time of training a deep neural network

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
import os
import yaml
import shutil
import glob
from typing import List, Dict, Tuple, Union, Any
from numbers import Number
import h5py
from PIL import Image
import numpy as np
import pandas as pd

# %%
from utils import harmonize_hdf5, read_harmonized_hdf5

# %% [markdown]
# ## current directory

# %%
print(os.getcwd())
# Out:
# /home/samehr/Desktop/cephal/cvmt/notebooks/prep_intermediate

# %% [markdown]
# ## load parameters

# %%
with open("../../code_configs/params.yaml") as f:
    params = yaml.safe_load(f)

# %%
print(params)
# Out:
# {'RAW_DATA_DIRECTORY': '../../data/raw', 'INTERMEDIATE_DATA_DIRECTORY': '../../data/intermediate', 'PRIMARY_DATA_DIRECTORY': '../../data/primary', 'ARTIFACTS_DATA_DIRECTORY': '../../artifacts', 'DATASET_1_RAW_ZIP_FILE_NAME': 'radiography-20221212T190109Z-001.zip', 'DATASET_1_RAW_ZIP_NEW_ANNOT_FILE_NAME': 'label_edited-20230122T143005Z-001.zip', 'DATASET_1_INTERMEDIATE_DIR_NAME': 'dataset_1', 'DATASET_1_UNWANTED_JSON_FIELDS': ['imageData'], 'DATASET_3_RAW_RAR_FILE_NAME': 'RawImage.rar', 'DATASET_3_RAW_DIR_NAME_TEMP': 'dataset_3_bmp', 'DATASET_3_RAW_DIR_NAME': 'dataset_3_raw_data', 'UNWANTED_JSON_FIELDS': ['imageData', 'imagePath'], 'DATASET_1_INTERM_DIR_NAME': 'dataset_1_interm_data-20230513T084705Z-001', 'DATASET_1_INTERM_IMG_DIR_NAME': ['image'], 'DATASET_1_INTERM_V_LANDMARKS_DIR_NAME': ['label'], 'DATASET_1_INTERM_F_LANDMARKS_DIR_NAME': None, 'DATASET_2_INTERM_DIR_NAME': 'dataset_2_interm_data-20230304T160421Z-001', 'DATASET_2_INTERM_IMG_DIR_NAME': ['image'], 'DATASET_2_INTERM_V_LANDMARKS_DIR_NAME': ['label'], 'DATASET_2_INTERM_F_LANDMARKS_DIR_NAME': None, 'DATASET_3_INTERM_DIR_NAME': 'dataset_3_interm_data-20230304T160433Z-001', 'DATASET_3_INTERM_IMG_DIR_NAME': ['training/image', 'test1/image', 'test2/image'], 'DATASET_3_INTERM_V_LANDMARKS_DIR_NAME': ['training/label', 'test1/label', 'test2/label'], 'DATASET_3_INTERM_F_LANDMARKS_DIR_NAME': 'AnnotationsByMD/400_senior', 'DATASET_1_EDGE_DETECT_SIGMA': 3, 'DATASET_2_EDGE_DETECT_SIGMA': 3, 'DATASET_3_EDGE_DETECT_SIGMA': 3, 'ARTIFACTS_GRAPHS_DIR_NAME': 'sample_graphs', 'TRAIN': {'METADATA_TABLE_NAME': 'metadata.hdf5', 'DATASETS_TO_INCLUDE': ['dataset_2', 'dataset_3'], 'TARGET_IMAGE_SIZE': [256, 256], 'GAUSSIAN_COORD2HEATMAP_STD': 3, 'MULTIPLE_TASKS': [{'TASK_ID': 3, 'BATCH_SIZE': 16}, {'TASK_ID': 4, 'BATCH_SIZE': 16}], 'SINGLE_TASK': {'TASK_ID': 3, 'BATCH_SIZE': 16}, 'MAX_EPOCHS': 10}, 'MODEL': {'DEVICE': 'cuda', 'PARAMS': {'backbone_encoder': 'efficientnet-b4', 'backbone_weights': 'imagenet', 'freeze_backbone': True, 'enc_chan_multiplier': 1, 'dec_chan_multiplier': 1, 'enc_out_chans': [4, 8, 16, 32, 64], 'dec_out_chans': [64, 32, 16, 8, 4], 'in_channels': 1, 'out_channels1': 1, 'out_channels2': 1, 'out_channels3': 13, 'out_channels4': 19}}}

# %%
metadata = []

for i in range(len(params['DATASET_1_INTERM_IMG_DIR_NAME'])):
    # create the directory paths
    img_foldername = params['DATASET_1_INTERM_IMG_DIR_NAME'][i]
    image_dir = os.path.join(
        params['INTERMEDIATE_DATA_DIRECTORY'],
        params['DATASET_1_INTERM_DIR_NAME'],
        img_foldername,
    )
    v_landmarks_foldername = params['DATASET_1_INTERM_V_LANDMARKS_DIR_NAME'][i]
    v_landmarks_dir = os.path.join(
        params['INTERMEDIATE_DATA_DIRECTORY'],
        params['DATASET_1_INTERM_DIR_NAME'],
        v_landmarks_foldername,
    )

    f_landmarks_dir = None
    if params['DATASET_1_INTERM_F_LANDMARKS_DIR_NAME'] is not None:
        f_landmarks_dir = os.path.join(
            params['INTERMEDIATE_DATA_DIRECTORY'],
            params['DATASET_1_INTERM_DIR_NAME'],
            params['DATASET_1_INTERM_F_LANDMARKS_DIR_NAME'],
        )

    # parse the directory
    image_filenames = os.listdir(image_dir)
    
    # harmonize all the images and annotations
    if len(params['DATASET_1_INTERM_IMG_DIR_NAME']) > 1:
        dev_set = img_foldername.split('/')[0]
    else:
        dev_set = None
        
    # load other parameters
    sigma = int(params['DATASET_1_EDGE_DETECT_SIGMA'])

    # Traverse the images and harmonize them one by one
    for image_filename in image_filenames:
        record_metadata = harmonize_hdf5(
            image_filename=image_filename,
            image_dir=image_dir,
            v_annot_dir=v_landmarks_dir,
            f_annot_dir=f_landmarks_dir,
            sigma=sigma,
        )
        record_metadata.update(
            {
                'source_image_filename': image_filename,
                'dataset': DATASET,
                'dev_set': dev_set,
            }
        )
        metadata.append(record_metadata)

# %%
metadata_df = pd.DataFrame(metadata)

# %% [markdown]
# ### write the metadata table to disk

# %%
metadata_df.head()
# Out:
#    v_annots_present  f_annots_present  edges_present f_annots_rows  \
# 0              True             False           True          None
# 1              True             False           True          None
# 2              True             False           True          None
# 3              True             False           True          None
# 4              True             False           True          None
#
#   f_annots_cols                                      harmonized_id  \
# 0          None  041281ee7fb89f6835a71c309b3b503e3d5a68fc46a608...
# 1          None  2cfa37a69916c8a45a51bb8beeb04425e07d2a22f694e0...
# 2          None  7201dc2be0b97f59a7901004d6496bbe84c440530776db...
# 3          None  2cd4487c03c72d1016ea0a72d1b21eb987878c90ae9eff...
# 4          None  27624a6eb37bbc8aafabe2075f423d573b189eae6f23fb...
#
#    v_annots_2_rows  v_annots_2_cols  v_annots_3_rows  v_annots_3_cols  \
# 0              3.0              2.0              5.0              2.0
# 1              3.0              2.0              5.0              2.0
# 2              3.0              2.0              5.0              2.0
# 3              3.0              2.0              5.0              2.0
# 4              3.0              2.0              5.0              2.0
#
#    v_annots_4_rows  v_annots_4_cols source_image_filename    dataset dev_set
# 0              5.0              2.0                45.jpg  dataset_1    None
# 1              5.0              2.0                92.jpg  dataset_1    None
# 2              5.0              2.0                43.jpg  dataset_1    None
# 3              5.0              2.0                 7.jpg  dataset_1    None
# 4              5.0              2.0               121.jpg  dataset_1    None

# %%
metadata_df.to_hdf(
    os.path.join(params['PRIMARY_DATA_DIRECTORY'], f'metadata_{DATASET}.hdf5'),
    key='df',
    index=False,
    mode='a',
    append=True,
    format='table',
)

# %% [markdown]
# ## sanity check some of them

# %%
i = 0
harmonized_ids = metadata_df.loc[metadata_df['dataset'] == DATASET,['harmonized_id']].to_numpy().ravel()
for harmonized_id in harmonized_ids:
    if i % 10 == 0:
        filename = harmonized_id+'.hdf5'
        image, edges, v_landmarks, f_landmarks = read_harmonized_hdf5(
            h5py_filename=filename,
        )
        print(filename)
        print("image.shape ", image.shape)
        print("edges.shape ", edges.shape)
        print("vertebrate_ids: ", v_landmarks['vertebrate_ids'])
        print("vertebral landmarks: ", v_landmarks['v_landmarks'])
        print("facial landmarks: ", f_landmarks['f_landmarks'])
        print()
    i += 1
# Out:
# 041281ee7fb89f6835a71c309b3b503e3d5a68fc46a608592d80180a60945ab1.hdf5
# image.shape  (1629, 1255)
# edges.shape  (1629, 1255)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[  80, 1037],
#        [ 121, 1038],
#        [ 175, 1059]]), array([[  80, 1061],
#        [  58, 1132],
#        [  99, 1146],
#        [ 149, 1177],
#        [ 163, 1104]]), array([[  53, 1159],
#        [  16, 1234],
#        [  57, 1245],
#        [ 100, 1285],
#        [ 128, 1220]])]
# facial landmarks:  None
#
# 2b6fcdd66bce779cd41dcf991ef11d1a23155951fdcbf6f7026854b737222e94.hdf5
# image.shape  (1629, 1254)
# edges.shape  (1629, 1254)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 85, 959],
#        [124, 966],
#        [161, 972]]), array([[  83,  986],
#        [  67, 1056],
#        [ 104, 1068],
#        [ 146, 1084],
#        [ 149, 1021]]), array([[  60, 1083],
#        [  38, 1154],
#        [  80, 1171],
#        [ 119, 1189],
#        [ 128, 1132]])]
# facial landmarks:  None
#
# e48885856ed0754b9d01aec42b833a793ca3995c0c5ba1f5f42a5a23c96adc5a.hdf5
# image.shape  (1629, 1255)
# edges.shape  (1629, 1255)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[  43, 1108],
#        [  74, 1104],
#        [ 134, 1131]]), array([[  47, 1130],
#        [  31, 1216],
#        [  60, 1215],
#        [ 119, 1243],
#        [ 132, 1177]]), array([[  32, 1228],
#        [   7, 1309],
#        [  48, 1320],
#        [ 100, 1345],
#        [ 112, 1287]])]
# facial landmarks:  None
#
# debeaf96ce445840ea2f96fb1d8e0d7bda782ea3547283b1c93b57836153cac7.hdf5
# image.shape  (1936, 2089)
# edges.shape  (1936, 2089)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 888, 1382],
#        [ 931, 1378],
#        [ 972, 1416]]), array([[ 876, 1398],
#        [ 862, 1506],
#        [ 910, 1500],
#        [ 964, 1536],
#        [ 971, 1438]]), array([[ 849, 1533],
#        [ 847, 1632],
#        [ 901, 1627],
#        [ 956, 1661],
#        [ 964, 1560]])]
# facial landmarks:  None
#
# 7ed9caa83b7058e3d19e0eb638ee1e75a70a48b5bd3ad090b4a03e4030e23740.hdf5
# image.shape  (458, 498)
# edges.shape  (458, 498)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[112, 341],
#        [126, 344],
#        [140, 360]]), array([[107, 343],
#        [ 91, 378],
#        [108, 383],
#        [120, 401],
#        [134, 370]]), array([[ 86, 382],
#        [ 73, 415],
#        [ 91, 418],
#        [106, 434],
#        [115, 406]])]
# facial landmarks:  None
#
# 35a52729da26082a64729f34bad6ed1351b724b47c7621f8a9544cdf6a34a750.hdf5
# image.shape  (1936, 2089)
# edges.shape  (1936, 2089)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 836, 1372],
#        [ 867, 1364],
#        [ 935, 1407]]), array([[ 826, 1394],
#        [ 808, 1478],
#        [ 842, 1478],
#        [ 909, 1512],
#        [ 908, 1428]]), array([[ 800, 1502],
#        [ 781, 1583],
#        [ 830, 1590],
#        [ 885, 1609],
#        [ 896, 1550]])]
# facial landmarks:  None
#
# dee5e1a809e419be8d1183774ee326d5ef768ca9044bf762be689a609212cb84.hdf5
# image.shape  (1629, 1255)
# edges.shape  (1629, 1255)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 115, 1096],
#        [ 164, 1090],
#        [ 212, 1129]]), array([[ 118, 1118],
#        [  90, 1222],
#        [ 140, 1220],
#        [ 192, 1263],
#        [ 212, 1170]]), array([[  92, 1243],
#        [  57, 1344],
#        [ 111, 1347],
#        [ 158, 1392],
#        [ 188, 1305]])]
# facial landmarks:  None
#
# b53cb48f0a3417e6bc2fd6ab4602b3646036994e2ba53cf55dc0ce4fec265220.hdf5
# image.shape  (562, 511)
# edges.shape  (562, 511)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[126, 428],
#        [140, 428],
#        [162, 440]]), array([[125, 438],
#        [121, 465],
#        [139, 469],
#        [159, 473],
#        [160, 456]]), array([[120, 476],
#        [114, 502],
#        [134, 507],
#        [152, 510],
#        [155, 494]])]
# facial landmarks:  None
#
# e1a77ea34d17001f847ee8a87b18d5e8a7104b0475f2601ec8eb7d867058a91f.hdf5
# image.shape  (1629, 1254)
# edges.shape  (1629, 1254)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 119, 1041],
#        [ 189, 1062],
#        [ 208, 1093]]), array([[  64, 1157],
#        [ 128, 1174],
#        [ 155, 1211],
#        [ 195, 1113],
#        [ 116, 1062]]), array([[   6, 1279],
#        [  73, 1297],
#        [ 101, 1331],
#        [ 139, 1233],
#        [  53, 1179]])]
# facial landmarks:  None
#
# 1e39a12de8bc2090c323e94cd5c22c4b9ef41a2560e2d7e5ddcf1d5972da72cf.hdf5
# image.shape  (1629, 1255)
# edges.shape  (1629, 1255)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 155, 1053],
#        [ 185, 1043],
#        [ 251, 1066]]), array([[ 162, 1070],
#        [ 155, 1152],
#        [ 196, 1154],
#        [ 240, 1185],
#        [ 244, 1109]]), array([[ 159, 1171],
#        [ 136, 1247],
#        [ 175, 1255],
#        [ 207, 1291],
#        [ 228, 1223]])]
# facial landmarks:  None
#
# 1292cfac9f649ac59b6b0dc05b05992a0dd389ee93e06ca76e7ba6aace4a0169.hdf5
# image.shape  (1629, 1255)
# edges.shape  (1629, 1255)
# vertebrate_ids:  None
# vertebral landmarks:  None
# facial landmarks:  None
#
# c6e184260eae9e25070913c3e09e38202b7d1e8fd416f0ea14840c14b01a868d.hdf5
# image.shape  (1629, 1255)
# edges.shape  (1629, 1255)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 157, 1050],
#        [ 185, 1039],
#        [ 254, 1064]]), array([[ 160, 1155],
#        [ 210, 1157],
#        [ 241, 1179],
#        [ 242, 1106],
#        [ 164, 1066]]), array([[ 133, 1247],
#        [ 183, 1260],
#        [ 203, 1292],
#        [ 226, 1222],
#        [ 159, 1167]])]
# facial landmarks:  None
#
# 6b7e4671259fd0e86ffb4699be0b286e2f69bcba6dc7e0abe44a839c5e7b833f.hdf5
# image.shape  (1629, 1255)
# edges.shape  (1629, 1255)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 150, 1158],
#        [ 188, 1148],
#        [ 261, 1175]]), array([[ 158, 1175],
#        [ 147, 1310],
#        [ 196, 1303],
#        [ 256, 1337],
#        [ 262, 1225]]), array([[ 153, 1325],
#        [ 125, 1445],
#        [ 175, 1445],
#        [ 228, 1488],
#        [ 250, 1377]])]
# facial landmarks:  None
#
# b5c8802340dcd7891234767f59f1969704b9be327cc8c2927002763b8e2e1d33.hdf5
# image.shape  (1629, 1254)
# edges.shape  (1629, 1254)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[  90, 1088],
#        [ 138, 1089],
#        [ 187, 1124]]), array([[  91, 1100],
#        [  69, 1202],
#        [ 115, 1203],
#        [ 165, 1241],
#        [ 183, 1153]]), array([[  60, 1216],
#        [  37, 1297],
#        [  80, 1310],
#        [ 126, 1346],
#        [ 146, 1266]])]
# facial landmarks:  None
#
# 48c08f95d186f64988539bf57221488b0677017e38d65daa37b4f491ec7a2a4e.hdf5
# image.shape  (1629, 1254)
# edges.shape  (1629, 1254)
# vertebrate_ids:  ['2', '3', '4']
# vertebral landmarks:  [array([[ 220, 1166],
#        [ 260, 1153],
#        [ 318, 1167]]), array([[ 226, 1185],
#        [ 209, 1281],
#        [ 259, 1285],
#        [ 307, 1311],
#        [ 315, 1205]]), array([[ 214, 1300],
#        [ 169, 1401],
#        [ 224, 1412],
#        [ 262, 1452],
#        [ 294, 1350]])]
# facial landmarks:  None

# %%
metadata_table = pd.read_hdf(
    os.path.join(params['PRIMARY_DATA_DIRECTORY'], f'metadata_{DATASET}.hdf5'),
    key='df',
)

# %%
metadata_table.head()
# Out:
#    v_annots_present  f_annots_present  edges_present f_annots_rows  \
# 0              True             False           True           NaN
# 1              True             False           True           NaN
# 2              True             False           True           NaN
# 3              True             False           True           NaN
# 4              True             False           True           NaN
#
#   f_annots_cols                                      harmonized_id  \
# 0           NaN  041281ee7fb89f6835a71c309b3b503e3d5a68fc46a608...
# 1           NaN  2cfa37a69916c8a45a51bb8beeb04425e07d2a22f694e0...
# 2           NaN  7201dc2be0b97f59a7901004d6496bbe84c440530776db...
# 3           NaN  2cd4487c03c72d1016ea0a72d1b21eb987878c90ae9eff...
# 4           NaN  27624a6eb37bbc8aafabe2075f423d573b189eae6f23fb...
#
#    v_annots_2_rows  v_annots_2_cols  v_annots_3_rows  v_annots_3_cols  \
# 0              3.0              2.0              5.0              2.0
# 1              3.0              2.0              5.0              2.0
# 2              3.0              2.0              5.0              2.0
# 3              3.0              2.0              5.0              2.0
# 4              3.0              2.0              5.0              2.0
#
#    v_annots_4_rows  v_annots_4_cols source_image_filename    dataset dev_set
# 0              5.0              2.0                45.jpg  dataset_1     NaN
# 1              5.0              2.0                92.jpg  dataset_1     NaN
# 2              5.0              2.0                43.jpg  dataset_1     NaN
# 3              5.0              2.0                 7.jpg  dataset_1     NaN
# 4              5.0              2.0               121.jpg  dataset_1     NaN

# %%
metadata_table.shape
# Out:
# (142, 15)

# %%
metadata_table.describe()
# Out:
#        v_annots_2_rows  v_annots_2_cols  v_annots_3_rows  v_annots_3_cols  \
# count            140.0            140.0            140.0            140.0
# mean               3.0              2.0              5.0              2.0
# std                0.0              0.0              0.0              0.0
# min                3.0              2.0              5.0              2.0
# 25%                3.0              2.0              5.0              2.0
# 50%                3.0              2.0              5.0              2.0
# 75%                3.0              2.0              5.0              2.0
# max                3.0              2.0              5.0              2.0
#
#        v_annots_4_rows  v_annots_4_cols
# count            140.0            140.0
# mean               5.0              2.0
# std                0.0              0.0
# min                5.0              2.0
# 25%                5.0              2.0
# 50%                5.0              2.0
# 75%                5.0              2.0
# max                5.0              2.0
